# %% [markdown]
# # Language Detection

# %%
from langdetect import detect, detect_langs

# %%
sentence = "she is reading a book."
print("Detected language: ", detect(sentence))
print("Probability: ", detect_langs(sentence))
# Out:
# Detected language:  en
# Probability:  [en:0.9999990028119119]

# %%
sentence = "यह एक शानदार दिन है"

print("Detect Language: ", detect(sentence))
print("Probability: ", detect_langs(sentence))
# Out:
# Detect Language:  hi
# Probability:  [hi:0.9999981319537046]

# %%
sentence = "روز فوق‌العاده‌ای است"

print("Detect Language: ", detect(sentence))
print("Probability: ", detect_langs(sentence))
# Out:
# Detect Language:  fa
# Probability:  [fa:0.9999988195907772]

# %% [markdown]
# # Language Translation

# %%
from googletrans import Translator

# %%
#Persian
translator = Translator()
sentence = "روز فوق‌العاده‌ای است"
translated_text = translator.translate(sentence, src="fa", dest="en")
print("Translated Text = ", translated_text.text)
# Out:
# Translated Text =  It is a wonderful day

# %%
# Irish
translator = Translator()
sentence = "Is lá iontach é"
translated_text = translator.translate(sentence, dest="hi")
print("Translated Text = ", translated_text.text)
# Out:
# Translated Text =  यह बहुत अच्छा दिन है

# %% [markdown]
# # Language Detection and Translation

# %%
from langdetect import detect
from googletrans import Translator

def detect_and_translate(text, target_lang):
    # Detect language
    result_lang = detect(text)

    # Translate language
    translator = Translator()
    translate_text = translator.translate(text, dest=target_lang).text

    return result_lang, translate_text
# Out:
# Running cells with '.venv (Python 3.11.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Sheryl/Desktop/proj 3 language detection/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %%
# example 1
# Sample sentence in Hindi
sentence = "Bonjour le monde"

# Detect and translate
result_lang, translate_text = detect_and_translate(sentence, target_lang='en')

print("Language:", result_lang)
print("Translation:", translate_text)
# Out:
# Language: fr
# Translation: Hello world

# %%
# example 2
# Sample sentence in English
sentence = "प्रौद्योगिक्याः जगत् अस्ति"

# Detect and translate
result_lang, translate_text = detect_and_translate(sentence, target_lang='en')

print("Language:", result_lang)
print("Translation:", translate_text)
# Out:
# Language: hi
# Translation: There is a world of technology
